# %% [markdown]
# <a href="https://colab.research.google.com/github/suyogy1-bot/Numpy_Pandas/blob/main/Class_notes/Pandas_Assignment_TechMart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Assignment - TechMart Sales Dataset
#
# Load `TechMart_Sales_300Rows.csv` and solve the following questions.

# %% [markdown]
# ## Q1. Load the CSV file.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('TechMart_Sales_300Rows.csv')

# %% [markdown]
# ## Q2. Display first 10 rows.

# %%
df.head(10)
# Out:
#   Order_ID     Customer_Name      Product     Category     Brand  Price  \
# 0  ORD1001    Anjali Gupta         Laptop  Electronics        HP  32598
# 1  ORD1002       Deepak Jain      Printer       Office     Canon   4405
# 2  ORD1003     Harsh Agrawal        Mouse  Accessories  Logitech  29393
# 3  ORD1004       Pooja Yadav      Monitor  Electronics      Dell  28721
# 4  ORD1005       Arjun Mehta  Smart Watch  Electronics     Apple   6195
# 5  ORD1006       Vivek Joshi  Smart Watch  Electronics     Apple  76174
# 6  ORD1007       Priya Singh        Mouse  Accessories  Logitech  50323
# 7  ORD1008       Arjun Mehta        Mouse  Accessories  Logitech   9858
# 8  ORD1009       Simran Kaur      Printer       Office     Canon  73500
# 9  ORD1010         Neha Soni      Monitor  Electronics      Dell  28153
#
#    Quantity    City  State  Order_Date Delivery_Status  Rating  \
# 0         2    Pune     MH  27-01-2025       Cancelled     2.0
# ...

# %% [markdown]
# ## Q3. Display last 5 rows.

# %%
df.tail(5)
# Out:
#     Order_ID    Customer_Name      Product     Category     Brand  Price  \
# 298  ORD1299    Harsh Agrawal     Keyboard  Accessories  Logitech  43227
# 299  ORD1300    Pooja Yadav    Smart Watch  Electronics     Apple  51951
# 300  ORD1011      Simran Kaur     Keyboard  Accessories  Logitech  18801
# 301  ORD1012      Deepak Jain      Printer       Office     Canon  29246
# 302  ORD1013      Rohit Patel     Keyboard  Accessories  Logitech  78672
#
#      Quantity    City State  Order_Date Delivery_Status  Rating  \
# 298         2  Nagpur    MH  30-01-2025         Pending     4.0
# 299         5  Jaipur    RJ  31-03-2025         Pending     1.0
# 300         2    Pune    MH  18-05-2025         Pending     5.0
# 301         2  Nagpur    MH  07-05-2025       Delivered     5.0
# 302         1  Jaipur    RJ  08-04-2025       Cancelled     4.0
#
#                                 Review Payment_Mode
# 298     Nice Product (Value for Money)  Net Banking
# ...

# %% [markdown]
# ## Q4. Check shape, columns and data types.

# %%
df.shape
# Out:
# (303, 14)

# %%
a = df.columns
for i in a:
  print(i)
# Out:
# Order_ID
# Customer_Name
# Product
# Category
# Brand
# Price
# Quantity
# City
# State
# Order_Date
# Delivery_Status
# Rating
# Review
# Payment_Mode

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         303 non-null    object
#  1   Customer_Name    303 non-null    object
#  2   Product          303 non-null    object
#  3   Category         303 non-null    object
#  4   Price            303 non-null    int64
#  5   Quantity         303 non-null    int64
#  6   City             303 non-null    object
#  7   State            303 non-null    object
#  8   Order_Date       303 non-null    object
#  9   Delivery_Status  303 non-null    object
#  10  Rating           303 non-null    float64
#  11  Review           303 non-null    object
#  12  Payment_Mode     303 non-null    object
#  13  Total_Amount     303 non-null    int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 33.3+ KB

# %% [markdown]
# ## Q5. Find null values.

# %%
df.isnull().sum() # only rating column is having null values
# Out:
# Order_ID           0
# Customer_Name      0
# Product            0
# Category           0
# Brand              0
# Price              0
# Quantity           0
# City               0
# State              0
# Order_Date         0
# Delivery_Status    0
# Rating             5
# Review             0
# Payment_Mode       0
# dtype: int64

# %% [markdown]
# ## Q6. Fill missing Rating with 0.

# %%
(df['Rating'] == 0).sum()
# Out:
# np.int64(0)

# %%
df['Rating'].isna().sum()
# Out:
# np.int64(5)

# %%
df['Rating'] = df['Rating'].fillna(0)

# %%
(df['Rating'] == 0).sum()
# Out:
# np.int64(5)

# %%
df['Rating'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Q7. Rename `Customer_Name` to `Customer`.

# %%
df['Customer_Name'] = df['Customer_Name'].rename('Customer')
df.head()
# Out:
#   Order_ID     Customer_Name      Product     Category     Brand  Price  \
# 0  ORD1001    Anjali Gupta         Laptop  Electronics        HP  32598
# 1  ORD1002       Deepak Jain      Printer       Office     Canon   4405
# 2  ORD1003     Harsh Agrawal        Mouse  Accessories  Logitech  29393
# 3  ORD1004       Pooja Yadav      Monitor  Electronics      Dell  28721
# 4  ORD1005       Arjun Mehta  Smart Watch  Electronics     Apple   6195
#
#    Quantity    City  State  Order_Date Delivery_Status  Rating  \
# 0         2    Pune     MH  27-01-2025       Cancelled     2.0
# 1         1  Bhopal     MP  01-03-2025       Cancelled     2.0
# 2         4  Jaipur     RJ  13-03-2025       Delivered     5.0
# 3         3   Delhi  Delhi  24-01-2025         Pending     1.0
# 4         4    Pune     MH  01-02-2025         Pending     5.0
#
#                             Review Payment_Mode
# 0          Poor Quality (Returned)          UPI
# 1                Amazing (5 Stars)          UPI
# ...

# %% [markdown]
# ## Q8. Delete `Brand` column.

# %%
df.drop('Brand', axis=1, inplace=True)
# here we are removing brand name column
# That's why axis = 1

df.head()
# Out:
#   Order_ID     Customer_Name      Product     Category  Price  Quantity  \
# 0  ORD1001    Anjali Gupta         Laptop  Electronics  32598         2
# 1  ORD1002       Deepak Jain      Printer       Office   4405         1
# 2  ORD1003     Harsh Agrawal        Mouse  Accessories  29393         4
# 3  ORD1004       Pooja Yadav      Monitor  Electronics  28721         3
# 4  ORD1005       Arjun Mehta  Smart Watch  Electronics   6195         4
#
#      City  State  Order_Date Delivery_Status  Rating  \
# 0    Pune     MH  27-01-2025       Cancelled     2.0
# 1  Bhopal     MP  01-03-2025       Cancelled     2.0
# 2  Jaipur     RJ  13-03-2025       Delivered     5.0
# 3   Delhi  Delhi  24-01-2025         Pending     1.0
# 4    Pune     MH  01-02-2025         Pending     5.0
#
#                             Review Payment_Mode
# 0          Poor Quality (Returned)          UPI
# 1                Amazing (5 Stars)          UPI
# 2  Average Quality (Late Delivery)   Debit Card
# ...

# %% [markdown]
# ## Q9. Create `Total_Amount = Price * Quantity`.

# %%
df['Total_Amount'] = df['Price'] * df['Quantity']
df.head()
# Out:
#   Order_ID     Customer_Name      Product     Category  Price  Quantity  \
# 0  ORD1001    Anjali Gupta         Laptop  Electronics  32598         2
# 1  ORD1002       Deepak Jain      Printer       Office   4405         1
# 2  ORD1003     Harsh Agrawal        Mouse  Accessories  29393         4
# 3  ORD1004       Pooja Yadav      Monitor  Electronics  28721         3
# 4  ORD1005       Arjun Mehta  Smart Watch  Electronics   6195         4
#
#      City  State  Order_Date Delivery_Status  Rating  \
# 0    Pune     MH  27-01-2025       Cancelled     2.0
# 1  Bhopal     MP  01-03-2025       Cancelled     2.0
# 2  Jaipur     RJ  13-03-2025       Delivered     5.0
# 3   Delhi  Delhi  24-01-2025         Pending     1.0
# 4    Pune     MH  01-02-2025         Pending     5.0
#
#                             Review Payment_Mode  Total_Amount
# 0          Poor Quality (Returned)          UPI         65196
# 1                Amazing (5 Stars)          UPI          4405
# ...

# %% [markdown]
# ## Q10. Display only Customer, Product and Total_Amount.

# %%
df[['Customer_Name', 'Product', 'Total_Amount']]
# Out:
#         Customer_Name      Product  Total_Amount
# 0      Anjali Gupta         Laptop         65196
# 1         Deepak Jain      Printer          4405
# 2       Harsh Agrawal        Mouse        117572
# 3         Pooja Yadav      Monitor         86163
# 4         Arjun Mehta  Smart Watch         24780
# ..                ...          ...           ...
# 298     Harsh Agrawal     Keyboard         86454
# 299     Pooja Yadav    Smart Watch        259755
# 300       Simran Kaur     Keyboard         37602
# 301       Deepak Jain      Printer         58492
# 302       Rohit Patel     Keyboard         78672
#
# [303 rows x 3 columns]

# %% [markdown]
# ## Q11. Show Delivered orders.

# %%
df['Delivery_Status'].unique()
# Out:
# array(['Cancelled', 'Delivered', 'Pending'], dtype=object)

# %%
df[df['Delivery_Status'] == 'Delivered'].head()
# Out:
#    Order_ID  Customer_Name  Product     Category  Price  Quantity       City  \
# 2   ORD1003  Harsh Agrawal    Mouse  Accessories  29393         4     Jaipur
# 8   ORD1009    Simran Kaur  Printer       Office  73500         2       Pune
# 11  ORD1012    Deepak Jain  Printer       Office  29246         2     Nagpur
# 16  ORD1017  Sakshi Sharma   Tablet  Electronics   3052         1  Hyderabad
# 17  ORD1018    Deepak Jain   Mobile  Electronics  64199         1     Indore
#
#    State  Order_Date Delivery_Status  Rating  \
# 2     RJ  13-03-2025       Delivered     5.0
# 8     MH  15-01-2025       Delivered     3.0
# 11    MH  07-05-2025       Delivered     5.0
# 16    TS  20-03-2025       Delivered     3.0
# 17    MP  02-02-2025       Delivered     5.0
#
#                                Review Payment_Mode  Total_Amount
# 2     Average Quality (Late Delivery)   Debit Card        117572
# 8   Excellent Product (Fast Delivery)  Credit Card        147000
# ...

# %%
df[df['Delivery_Status'] == 'Delivered'].shape
# Out:
# (88, 14)

# %%
(df['Delivery_Status'] == 'Delivered').sum()
# Out:
# np.int64(88)

# %% [markdown]
# ## Q12. Show products with Price > 50000.

# %%
df[df['Price'] > 50000].head()
# Out:
#    Order_ID Customer_Name      Product     Category  Price  Quantity    City  \
# 5   ORD1006   Vivek Joshi  Smart Watch  Electronics  76174         2  Nagpur
# 6   ORD1007   Priya Singh        Mouse  Accessories  50323         3  Indore
# 8   ORD1009   Simran Kaur      Printer       Office  73500         2    Pune
# 12  ORD1013   Rohit Patel     Keyboard  Accessories  78672         1  Jaipur
# 17  ORD1018   Deepak Jain       Mobile  Electronics  64199         1  Indore
#
#    State  Order_Date Delivery_Status  Rating  \
# 5     MH  12-01-2025       Cancelled     1.0
# 6     MP  12-06-2025         Pending     4.0
# 8     MH  15-01-2025       Delivered     3.0
# 12    RJ  08-04-2025       Cancelled     4.0
# 17    MP  02-02-2025       Delivered     5.0
#
#                                Review Payment_Mode  Total_Amount
# 5             Very Nice (Recommended)  Credit Card        152348
# 6     Average Quality (Late Delivery)  Credit Card        150969
# ...

# %%
df[df['Price'] > 50000].shape
# Out:
# (120, 14)

# %% [markdown]
# ## Q13. Show customers from Bhopal.

# %%
df[df['City'] == 'Bhopal'].head()
# Out:
#    Order_ID Customer_Name    Product     Category  Price  Quantity    City  \
# 1   ORD1002   Deepak Jain    Printer       Office   4405         1  Bhopal
# 13  ORD1014    Nikita Rao  Headphone  Accessories  15514         5  Bhopal
# 43  ORD1044    Karan Shah      Mouse  Accessories  25813         4  Bhopal
# 61  ORD1062   Mohit Gupta    Speaker  Accessories  51468         3  Bhopal
# 63  ORD1064   Simran Kaur   Keyboard  Accessories  34599         4  Bhopal
#
#    State  Order_Date Delivery_Status  Rating                           Review  \
# 1     MP  01-03-2025       Cancelled     2.0                Amazing (5 Stars)
# 13    MP  14-06-2025         Pending     3.0         Good Product (Satisfied)
# 43    MP  13-03-2025       Delivered     3.0    Worth Buying (Happy Customer)
# 61    MP  12-02-2025         Pending     4.0  Average Quality (Late Delivery)
# 63    MP  24-02-2025         Pending     3.0          Bad Packaging (Delayed)
#
#    Payment_Mode  Total_Amount
# ...

# %%
df[df['City'] == 'Bhopal'].shape
# Out:
# (32, 14)

# %% [markdown]
# ## Q14. Show Rating >= 4.

# %%
df[df['Rating'] >= 4].head()
# Out:
#    Order_ID  Customer_Name      Product     Category  Price  Quantity    City  \
# 2   ORD1003  Harsh Agrawal        Mouse  Accessories  29393         4  Jaipur
# 4   ORD1005    Arjun Mehta  Smart Watch  Electronics   6195         4    Pune
# 6   ORD1007    Priya Singh        Mouse  Accessories  50323         3  Indore
# 10  ORD1011    Simran Kaur     Keyboard  Accessories  18801         2    Pune
# 11  ORD1012    Deepak Jain      Printer       Office  29246         2  Nagpur
#
#    State  Order_Date Delivery_Status  Rating  \
# 2     RJ  13-03-2025       Delivered     5.0
# 4     MH  01-02-2025         Pending     5.0
# 6     MP  12-06-2025         Pending     4.0
# 10    MH  18-05-2025         Pending     5.0
# 11    MH  07-05-2025       Delivered     5.0
#
#                                Review Payment_Mode  Total_Amount
# 2     Average Quality (Late Delivery)   Debit Card        117572
# 4            Good Product (Satisfied)  Net Banking         24780
# ...

# %%
df[df['Rating'] >= 4].shape
# Out:
# (132, 14)

# %% [markdown]
# ## Q15. Show Electronics category.

# %%
df['Category'].unique()
# Out:
# array(['Electronics', 'Office', 'Accessories'], dtype=object)

# %%
df[df['Category'] == 'Electronics'].head()
# Out:
#   Order_ID     Customer_Name      Product     Category  Price  Quantity  \
# 0  ORD1001    Anjali Gupta         Laptop  Electronics  32598         2
# 3  ORD1004       Pooja Yadav      Monitor  Electronics  28721         3
# 4  ORD1005       Arjun Mehta  Smart Watch  Electronics   6195         4
# 5  ORD1006       Vivek Joshi  Smart Watch  Electronics  76174         2
# 9  ORD1010         Neha Soni      Monitor  Electronics  28153         5
#
#      City  State  Order_Date Delivery_Status  Rating  \
# 0    Pune     MH  27-01-2025       Cancelled     2.0
# 3   Delhi  Delhi  24-01-2025         Pending     1.0
# 4    Pune     MH  01-02-2025         Pending     5.0
# 5  Nagpur     MH  12-01-2025       Cancelled     1.0
# 9  Indore     MP  24-02-2025       Cancelled     3.0
#
#                            Review Payment_Mode  Total_Amount
# 0         Poor Quality (Returned)          UPI         65196
# 3        Good Product (Satisfied)  Credit Card         86163
# ...

# %% [markdown]
# ## Q16. Sort by Price (Ascending).

# %%
df.sort_values(by='Price').head()
# Out:
#     Order_ID  Customer_Name      Product     Category  Price  Quantity  \
# 101  ORD1102    Pooja Yadav    Headphone  Accessories    836         3
# 14   ORD1015    Mohit Gupta     Keyboard  Accessories    925         3
# 20   ORD1021     Karan Shah  Smart Watch  Electronics   1442         1
# 146  ORD1147      Neha Soni  Smart Watch  Electronics   1507         2
# 279  ORD1280  Sakshi Sharma       Tablet  Electronics   2117         3
#
#           City State  Order_Date Delivery_Status  Rating  \
# 101       Pune    MH  31-05-2025       Cancelled     3.0
# 14   Hyderabad    TS  15-02-2025       Cancelled     5.0
# 20      Mumbai    MH  28-02-2025       Delivered     1.0
# 146     Bhopal    MP  24-02-2025       Delivered     3.0
# 279     Jaipur    RJ  10-04-2025       Delivered     4.0
#
#                                 Review Payment_Mode  Total_Amount
# 101     Nice Product (Value for Money)         Cash          2508
# ...

# %% [markdown]
# ## Q17. Sort by Total_Amount (Descending).

# %%
df.sort_values(by='Total_Amount', ascending=False).head()
# Out:
#     Order_ID  Customer_Name      Product     Category  Price  Quantity  \
# 213  ORD1214    Riya Tiwari      Speaker  Accessories  79963         5
# 282  ORD1283     Nikita Rao        Mouse  Accessories  78331         5
# 62   ORD1063  Harsh Agrawal       Laptop  Electronics  78080         5
# 216  ORD1217  Sakshi Sharma      Speaker  Accessories  76321         5
# 249  ORD1250     Karan Shah  Smart Watch  Electronics  76190         5
#
#           City  State  Order_Date Delivery_Status  Rating  \
# 213      Delhi  Delhi  25-03-2025       Cancelled     2.0
# 282  Hyderabad     TS  28-04-2025       Delivered     2.0
# 62      Jaipur     RJ  22-01-2025       Cancelled     1.0
# 216       Pune     MH  14-01-2025       Cancelled     2.0
# 249     Nagpur     MH  02-03-2025         Pending     3.0
#
#                               Review Payment_Mode  Total_Amount
# 213          Bad Packaging (Delayed)         Cash        399815
# ...

# %% [markdown]
# ## Q18. Sort by City then Price.

# %%
df.sort_values(by=['City', 'Price']).head()

# This will first sort by cities then based on those cities
# it will sort by price.
# For Example: It will sort cities by ascending order like "Bhopal"
# Then we have multiple values of bhopal, so ...
# It will arrange prices in asceding order within Bhopal.
# Out:
#     Order_ID Customer_Name      Product     Category  Price  Quantity    City  \
# 146  ORD1147     Neha Soni  Smart Watch  Electronics   1507         2  Bhopal
# 1    ORD1002   Deepak Jain      Printer       Office   4405         1  Bhopal
# 242  ORD1243   Arjun Mehta       Mobile  Electronics   9546         4  Bhopal
# 255  ORD1256    Nikita Rao      Printer       Office  10039         2  Bhopal
# 273  ORD1274   Riya Tiwari       Tablet  Electronics  13303         4  Bhopal
#
#     State  Order_Date Delivery_Status  Rating  \
# 146    MP  24-02-2025       Delivered     3.0
# 1      MP  01-03-2025       Cancelled     2.0
# 242    MP  15-03-2025         Pending     1.0
# 255    MP  21-06-2025       Cancelled     5.0
# 273    MP  20-01-2025         Pending     2.0
#
#                               Review Payment_Mode  Total_Amount
# 146    Worth Buying (Happy Customer)  Credit Card          3014
# 1                  Amazing (5 Stars)          UPI          4405
# ...

# %% [markdown]
# ## Q19. Convert Customer to uppercase.

# %%
df['Customer_Name'] = df['Customer_Name'].str.upper()
df.head()
# Out:
#   Order_ID     Customer_Name      Product     Category  Price  Quantity  \
# 0  ORD1001    ANJALI GUPTA         Laptop  Electronics  32598         2
# 1  ORD1002       DEEPAK JAIN      Printer       Office   4405         1
# 2  ORD1003     HARSH AGRAWAL        Mouse  Accessories  29393         4
# 3  ORD1004       POOJA YADAV      Monitor  Electronics  28721         3
# 4  ORD1005       ARJUN MEHTA  Smart Watch  Electronics   6195         4
#
#      City  State  Order_Date Delivery_Status  Rating  \
# 0    Pune     MH  27-01-2025       Cancelled     2.0
# 1  Bhopal     MP  01-03-2025       Cancelled     2.0
# 2  Jaipur     RJ  13-03-2025       Delivered     5.0
# 3   Delhi  Delhi  24-01-2025         Pending     1.0
# 4    Pune     MH  01-02-2025         Pending     5.0
#
#                             Review Payment_Mode  Total_Amount
# 0          Poor Quality (Returned)          UPI         65196
# 1                Amazing (5 Stars)          UPI          4405
# ...

# %% [markdown]
# ## Q20. Convert Product to lowercase.

# %%
df['Product'] = df['Product'].str.lower()
df.head()
# Out:
#   Order_ID     Customer_Name      Product     Category  Price  Quantity  \
# 0  ORD1001    ANJALI GUPTA         laptop  Electronics  32598         2
# 1  ORD1002       DEEPAK JAIN      printer       Office   4405         1
# 2  ORD1003     HARSH AGRAWAL        mouse  Accessories  29393         4
# 3  ORD1004       POOJA YADAV      monitor  Electronics  28721         3
# 4  ORD1005       ARJUN MEHTA  smart watch  Electronics   6195         4
#
#      City  State  Order_Date Delivery_Status  Rating  \
# 0    Pune     MH  27-01-2025       Cancelled     2.0
# 1  Bhopal     MP  01-03-2025       Cancelled     2.0
# 2  Jaipur     RJ  13-03-2025       Delivered     5.0
# 3   Delhi  Delhi  24-01-2025         Pending     1.0
# 4    Pune     MH  01-02-2025         Pending     5.0
#
#                             Review Payment_Mode  Total_Amount
# 0          Poor Quality (Returned)          UPI         65196
# 1                Amazing (5 Stars)          UPI          4405
# ...

# %% [markdown]
# ## Q21. Remove everything after '(' from Review.

# %%
b = "Average Quality (Late Delivery)"
b_list = b.split('(')
b_list
# Out:
# ['Average Quality ', 'Late Delivery)']

# %%
b_list[0]
# Out:
# 'Average Quality '

# %%
c = b_list[0].strip()
c
# Out:
# 'Average Quality'

# %%
a = df['Review'].str.split('(')
a.str[0]
# Out:
# 0           Poor Quality
# 1                Amazing
# 2        Average Quality
# 3           Good Product
# 4           Good Product
#               ...
# 298         Nice Product
# 299         Nice Product
# 300              Amazing
# 301    Excellent Product
# 302         Nice Product
# Name: Review, Length: 303, dtype: object

# %%
df['Review'] = df['Review'].str.split('(').str[0]
df.head()
# Out:
#   Order_ID     Customer_Name      Product     Category  Price  Quantity  \
# 0  ORD1001    ANJALI GUPTA         laptop  Electronics  32598         2
# 1  ORD1002       DEEPAK JAIN      printer       Office   4405         1
# 2  ORD1003     HARSH AGRAWAL        mouse  Accessories  29393         4
# 3  ORD1004       POOJA YADAV      monitor  Electronics  28721         3
# 4  ORD1005       ARJUN MEHTA  smart watch  Electronics   6195         4
#
#      City  State  Order_Date Delivery_Status  Rating            Review  \
# 0    Pune     MH  27-01-2025       Cancelled     2.0     Poor Quality
# 1  Bhopal     MP  01-03-2025       Cancelled     2.0          Amazing
# 2  Jaipur     RJ  13-03-2025       Delivered     5.0  Average Quality
# 3   Delhi  Delhi  24-01-2025         Pending     1.0     Good Product
# 4    Pune     MH  01-02-2025         Pending     5.0     Good Product
#
#   Payment_Mode  Total_Amount
# 0          UPI         65196
# 1          UPI          4405
# ...

# %% [markdown]
# ## Q22. Find customers whose names start with 'A'.

# %%
df[df['Customer_Name'].str.startswith('A')].head()
# Out:
#    Order_ID Customer_Name      Product     Category  Price  Quantity  \
# 4   ORD1005   ARJUN MEHTA  smart watch  Electronics   6195         4
# 7   ORD1008   ARJUN MEHTA        mouse  Accessories   9858         5
# 22  ORD1023   AKASH DUBEY        mouse  Accessories  53854         2
# 29  ORD1030    AMAN VERMA  smart watch  Electronics  66409         5
# 31  ORD1032    AMAN VERMA  smart watch  Electronics  55448         5
#
#          City State  Order_Date Delivery_Status  Rating         Review  \
# 4        Pune    MH  01-02-2025         Pending     5.0  Good Product
# 7        Pune    MH  17-05-2025       Cancelled     2.0     Very Nice
# 22  Hyderabad    TS  25-01-2025       Cancelled     1.0     Excellent
# 29  Hyderabad    TS  15-01-2025       Cancelled     2.0  Good Product
# 31     Indore    MP  14-05-2025         Pending     5.0  Worth Buying
#
#    Payment_Mode  Total_Amount
# 4   Net Banking         24780
# 7          Cash         49290
# 22  Credit Card        107708
# ...

# %% [markdown]
# ## Q23. Find reviews containing 'Good'.

# %%
df[df['Review'].str.contains('Good')].head()
# Out:
#    Order_ID Customer_Name      Product     Category  Price  Quantity  \
# 3   ORD1004   POOJA YADAV      monitor  Electronics  28721         3
# 4   ORD1005   ARJUN MEHTA  smart watch  Electronics   6195         4
# 13  ORD1014    NIKITA RAO    headphone  Accessories  15514         5
# 14  ORD1015   MOHIT GUPTA     keyboard  Accessories    925         3
# 29  ORD1030    AMAN VERMA  smart watch  Electronics  66409         5
#
#          City  State  Order_Date Delivery_Status  Rating         Review  \
# 3       Delhi  Delhi  24-01-2025         Pending     1.0  Good Product
# 4        Pune     MH  01-02-2025         Pending     5.0  Good Product
# 13     Bhopal     MP  14-06-2025         Pending     3.0  Good Product
# 14  Hyderabad     TS  15-02-2025       Cancelled     5.0  Good Product
# 29  Hyderabad     TS  15-01-2025       Cancelled     2.0  Good Product
#
#    Payment_Mode  Total_Amount
# 3   Credit Card         86163
# 4   Net Banking         24780
# ...

# %% [markdown]
# ## Q24. Remove extra spaces from Customer.

# %%
df['Customer_Name'] = df['Customer_Name'].str.strip()
df.head()
# Out:
#   Order_ID  Customer_Name      Product     Category  Price  Quantity    City  \
# 0  ORD1001   ANJALI GUPTA       laptop  Electronics  32598         2    Pune
# 1  ORD1002    DEEPAK JAIN      printer       Office   4405         1  Bhopal
# 2  ORD1003  HARSH AGRAWAL        mouse  Accessories  29393         4  Jaipur
# 3  ORD1004    POOJA YADAV      monitor  Electronics  28721         3   Delhi
# 4  ORD1005    ARJUN MEHTA  smart watch  Electronics   6195         4    Pune
#
#    State  Order_Date Delivery_Status  Rating            Review Payment_Mode  \
# 0     MH  27-01-2025       Cancelled     2.0     Poor Quality           UPI
# 1     MP  01-03-2025       Cancelled     2.0          Amazing           UPI
# 2     RJ  13-03-2025       Delivered     5.0  Average Quality    Debit Card
# 3  Delhi  24-01-2025         Pending     1.0     Good Product   Credit Card
# 4     MH  01-02-2025         Pending     5.0     Good Product   Net Banking
#
#    Total_Amount
# 0         65196
# ...

# %% [markdown]
# ## Q25. Category-wise total sales.

# %%
df.groupby('Category')['Total_Amount'].sum()
# Out:
# Category
# Accessories    15627647
# Electronics    17974270
# Office          3383852
# Name: Total_Amount, dtype: int64

# %% [markdown]
# ## Q26. Brand-wise average price.

# %%
# This will give error because we have already dropped the brand column

df.groupby('Brand')['Price'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_6203/3850656100.py in <cell line: 0>()
#       1 # This will give error because we have already dropped the brand column
#       2
# ----> 3 df.groupby('Brand')['Price'].mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
# ...

# %% [markdown]
# ## Q27. Category-wise maximum price.

# %%
df.groupby('Category')['Price'].max()
# Out:
# Category
# Accessories    79963
# Electronics    79982
# Office         78866
# Name: Price, dtype: int64

# %% [markdown]
# ## Q28. City-wise total quantity.

# %%
df.groupby('City')['Quantity'].sum()
# Out:
# City
# Bhopal       112
# Delhi        103
# Hyderabad    122
# Indore       106
# Jaipur       136
# Mumbai        84
# Nagpur       111
# Pune         121
# Name: Quantity, dtype: int64

# %% [markdown]
# ## Q29. Payment mode-wise average rating.

# %%
df.groupby('Payment_Mode')['Rating'].mean()
# Out:
# Payment_Mode
# Cash           3.133333
# Credit Card    3.046154
# Debit Card     3.526316
# Net Banking    2.745455
# UPI            2.893939
# Name: Rating, dtype: float64

# %% [markdown]
# ## Q30. Count Delivery_Status.

# %%
df['Delivery_Status'].value_counts()
# Out:
# Delivery_Status
# Cancelled    108
# Pending      107
# Delivered     88
# Name: count, dtype: int64

# %% [markdown]
# ## Q31. Count Category.

# %%
df['Category'].value_counts()
# Out:
# Category
# Electronics    145
# Accessories    123
# Office          35
# Name: count, dtype: int64

# %% [markdown]
# ## Q32. Count Payment_Mode.

# %%
df['Payment_Mode'].value_counts()
# Out:
# Payment_Mode
# UPI            66
# Credit Card    65
# Cash           60
# Debit Card     57
# Net Banking    55
# Name: count, dtype: int64

# %% [markdown]
# ## Q33. Top 5 highest sales.

# %%
df.sort_values(by='Total_Amount', ascending=False).head(5)
# Out:
#     Order_ID  Customer_Name      Product     Category  Price  Quantity  \
# 213  ORD1214    RIYA TIWARI      speaker  Accessories  79963         5
# 282  ORD1283     NIKITA RAO        mouse  Accessories  78331         5
# 62   ORD1063  HARSH AGRAWAL       laptop  Electronics  78080         5
# 216  ORD1217  SAKSHI SHARMA      speaker  Accessories  76321         5
# 249  ORD1250     KARAN SHAH  smart watch  Electronics  76190         5
#
#           City  State  Order_Date Delivery_Status  Rating            Review  \
# 213      Delhi  Delhi  25-03-2025       Cancelled     2.0    Bad Packaging
# 282  Hyderabad     TS  28-04-2025       Delivered     2.0  Average Quality
# 62      Jaipur     RJ  22-01-2025       Cancelled     1.0        Excellent
# 216       Pune     MH  14-01-2025       Cancelled     2.0     Nice Product
# 249     Nagpur     MH  02-03-2025         Pending     3.0  Average Quality
#
#     Payment_Mode  Total_Amount
# 213         Cash        399815
# ...

# %% [markdown]
# ## Q34. Bottom 5 sales.

# %%
df.sort_values(by='Total_Amount', ascending=False).tail(5)
# Out:
#     Order_ID  Customer_Name      Product     Category  Price  Quantity  \
# 16   ORD1017  SAKSHI SHARMA       tablet  Electronics   3052         1
# 146  ORD1147      NEHA SONI  smart watch  Electronics   1507         2
# 14   ORD1015    MOHIT GUPTA     keyboard  Accessories    925         3
# 101  ORD1102    POOJA YADAV    headphone  Accessories    836         3
# 20   ORD1021     KARAN SHAH  smart watch  Electronics   1442         1
#
#           City State  Order_Date Delivery_Status  Rating              Review  \
# 16   Hyderabad    TS  20-03-2025       Delivered     3.0  Excellent Product
# 146     Bhopal    MP  24-02-2025       Delivered     3.0       Worth Buying
# 14   Hyderabad    TS  15-02-2025       Cancelled     5.0       Good Product
# 101       Pune    MH  31-05-2025       Cancelled     3.0       Nice Product
# 20      Mumbai    MH  28-02-2025       Delivered     1.0  Excellent Product
#
#     Payment_Mode  Total_Amount
# 16          Cash          3052
# ...

# %% [markdown]
# ## Q35. Find duplicate rows.

# %%
df.duplicated().sum()
# Out:
# np.int64(3)

# %%
df[df.duplicated()]
# Out:
#     Order_ID Customer_Name   Product     Category  Price  Quantity    City  \
# 300  ORD1011   SIMRAN KAUR  keyboard  Accessories  18801         2    Pune
# 301  ORD1012   DEEPAK JAIN   printer       Office  29246         2  Nagpur
# 302  ORD1013   ROHIT PATEL  keyboard  Accessories  78672         1  Jaipur
#
#     State  Order_Date Delivery_Status  Rating              Review  \
# 300    MH  18-05-2025         Pending     5.0            Amazing
# 301    MH  07-05-2025       Delivered     5.0  Excellent Product
# 302    RJ  08-04-2025       Cancelled     4.0       Nice Product
#
#     Payment_Mode  Total_Amount
# 300   Debit Card         37602
# 301          UPI         58492
# 302  Net Banking         78672

# %%
# 1. See which positions are duplicates
df.duplicated()

# 2. See only the duplicates
df[df.duplicated()]

# 3. See original + duplicate together
dupe_mask = df.duplicated(keep=False)
df[dupe_mask].sort_values(by=df.columns.tolist())
# Out:
#     Order_ID Customer_Name   Product     Category  Price  Quantity    City  \
# 10   ORD1011   SIMRAN KAUR  keyboard  Accessories  18801         2    Pune
# 300  ORD1011   SIMRAN KAUR  keyboard  Accessories  18801         2    Pune
# 11   ORD1012   DEEPAK JAIN   printer       Office  29246         2  Nagpur
# 301  ORD1012   DEEPAK JAIN   printer       Office  29246         2  Nagpur
# 12   ORD1013   ROHIT PATEL  keyboard  Accessories  78672         1  Jaipur
# 302  ORD1013   ROHIT PATEL  keyboard  Accessories  78672         1  Jaipur
#
#     State  Order_Date Delivery_Status  Rating              Review  \
# 10     MH  18-05-2025         Pending     5.0            Amazing
# 300    MH  18-05-2025         Pending     5.0            Amazing
# 11     MH  07-05-2025       Delivered     5.0  Excellent Product
# 301    MH  07-05-2025       Delivered     5.0  Excellent Product
# 12     RJ  08-04-2025       Cancelled     4.0       Nice Product
# ...

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# ## Q36. Remove duplicate rows.

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (300, 14)

# %% [markdown]
# ## Q37. Save cleaned data as `Cleaned_TechMart.csv`.

# %%
df.to_csv('Cleaned_TechMart.csv', index=False)

# %%
# I can download the above cleaned csv file from the left “Files” panel in Colab.
